# %% [markdown]
# # Linear Regression with Keras

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.optimizers import Adam, SGD

# %%
df = pd.read_csv('weight-height.csv')
X = df[['Height']].values
y_true = df['Weight'].values

df.head()
# Out:
#   Gender     Height      Weight
# 0   Male  73.847017  241.893563
# 1   Male  68.781904  162.310473
# 2   Male  74.110105  212.740856
# 3   Male  71.730978  220.042470
# 4   Male  69.881796  206.349801

# %%
df.plot(kind='scatter',
        x='Height',
        y='Weight',
        title='Weight and Height in adults')
# Out:
# <AxesSubplot:title={'center':'Weight and Height in adults'}, xlabel='Height', ylabel='Weight'>

# %%
model = Sequential()
model.add(Dense(1, input_shape=(1,)))
model.compile(Adam(learning_rate=0.8), 'mean_squared_error')

model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 1)                 2
#
# =================================================================
# Total params: 2
# Trainable params: 2
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.fit(X, y_true, epochs=40)
# Out:
# Epoch 1/40
# 313/313 [==============================] - 1s 2ms/step - loss: 606.3258
# Epoch 2/40
# 313/313 [==============================] - 1s 2ms/step - loss: 538.7108
# Epoch 3/40
# 313/313 [==============================] - 1s 2ms/step - loss: 467.9531
# Epoch 4/40
# 313/313 [==============================] - 1s 2ms/step - loss: 436.6567
# Epoch 5/40
# 313/313 [==============================] - 1s 2ms/step - loss: 387.5451
# Epoch 6/40
# 313/313 [==============================] - 1s 2ms/step - loss: 340.9939
# Epoch 7/40
# 313/313 [==============================] - 1s 2ms/step - loss: 306.9097
# Epoch 8/40
# 313/313 [==============================] - 1s 2ms/step - loss: 287.4292
# Epoch 9/40
# 313/313 [==============================] - 1s 3ms/step - loss: 255.6591
# Epoch 10/40
# 313/313 [==============================] - 1s 3ms/step - loss: 247.5520
# Epoch 11/40
# 313/313 [==============================] - 1s 3ms/step - loss: 230.4689
# Epoch 12/40
# 313/313 [==============================] - 1s 3ms/step - loss: 219.2641
# Epoch 13/40
# 313/313 [==============================] - 1s 3ms/step - loss: 219.1796
# Epoch 14/40
# 313/313 [==============================] - 1s 3ms/step - loss: 209.2711
# Epoch 15/40
# 313/313 [==============================] - 1s 2ms/step - loss: 192.3166
# Epoch 16/40
# 313/313 [==============================] - 1s 2ms/step - loss: 184.5757
# Epoch 17/40
# 313/313 [==============================] - 1s 2ms/step - loss: 175.8017
# Epoch 18/40
# 313/313 [==============================] - 1s 2ms/step - loss: 184.6407
# Epoch 19/40
# 313/313 [==============================] - 1s 2ms/step - loss: 188.8804
# Epoch 20/40
# 313/313 [==============================] - 1s 2ms/step - loss: 213.5327
# Epoch 21/40
# 313/313 [==============================] - 1s 2ms/step - loss: 174.7437
# Epoch 22/40
# 313/313 [==============================] - 1s 2ms/step - loss: 175.3294
# Epoch 23/40
# 313/313 [==============================] - 1s 2ms/step - loss: 171.7675
# Epoch 24/40
# 313/313 [==============================] - 1s 2ms/step - loss: 176.1954
# Epoch 25/40
# 313/313 [==============================] - 1s 2ms/step - loss: 179.7868
# Epoch 26/40
# 313/313 [==============================] - 1s 2ms/step - loss: 184.3923
# Epoch 27/40
# 313/313 [==============================] - 1s 2ms/step - loss: 185.9423
# Epoch 28/40
# 313/313 [==============================] - 1s 2ms/step - loss: 170.0680
# Epoch 29/40
# 313/313 [==============================] - 1s 2ms/step - loss: 186.1694
# Epoch 30/40
# 313/313 [==============================] - 1s 2ms/step - loss: 174.4185
# Epoch 31/40
# 313/313 [==============================] - 1s 2ms/step - loss: 179.3180
# Epoch 32/40
# 313/313 [==============================] - 1s 2ms/step - loss: 177.8683
# Epoch 33/40
# 313/313 [==============================] - 1s 2ms/step - loss: 176.2673
# Epoch 34/40
# 313/313 [==============================] - 1s 2ms/step - loss: 180.4852
# Epoch 35/40
# 313/313 [==============================] - 1s 2ms/step - loss: 183.6168
# Epoch 36/40
# 313/313 [==============================] - 1s 2ms/step - loss: 188.0348
# Epoch 37/40
# 313/313 [==============================] - 1s 2ms/step - loss: 184.1208
# Epoch 38/40
# 313/313 [==============================] - 1s 2ms/step - loss: 173.0020
# Epoch 39/40
# 313/313 [==============================] - 1s 2ms/step - loss: 178.5181
# Epoch 40/40
# 313/313 [==============================] - 1s 2ms/step - loss: 171.0624

# %%
y_pred = model.predict(X)
# Out:
# 313/313 [==============================] - 1s 2ms/step

# %%
df.plot(kind='scatter',
        x='Height',
        y='Weight',
        title='Weight and Height in adults')
plt.plot(X, y_pred, color='red')
plt.show()

# %%
W, B = model.get_weights()

# %%
W
# Out:
# array([[7.625988]], dtype=float32)

# %%
B
# Out:
# array([-348.37305], dtype=float32)
