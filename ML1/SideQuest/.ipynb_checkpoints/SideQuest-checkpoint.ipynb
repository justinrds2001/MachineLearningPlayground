# %% [markdown]
# # Predict North America Sales with Linear Regression

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

df = pd.read_csv('vgsales.csv', sep=',')
df.head()
# Out:
#    Rank                      Name Platform    Year         Genre Publisher  \
# 0     1                Wii Sports      Wii  2006.0        Sports  Nintendo
# 1     2         Super Mario Bros.      NES  1985.0      Platform  Nintendo
# 2     3            Mario Kart Wii      Wii  2008.0        Racing  Nintendo
# 3     4         Wii Sports Resort      Wii  2009.0        Sports  Nintendo
# 4     5  Pokemon Red/Pokemon Blue       GB  1996.0  Role-Playing  Nintendo
#
#    NA_Sales  EU_Sales  JP_Sales  Other_Sales  Global_Sales
# 0     41.49     29.02      3.77         8.46         82.74
# 1     29.08      3.58      6.81         0.77         40.24
# 2     15.85     12.88      3.79         3.31         35.82
# 3     15.75     11.01      3.28         2.96         33.00
# 4     11.27      8.89     10.22         1.00         31.37

# %%
numeric_df = df.select_dtypes(include=['number'])
correlation_matrix = numeric_df.corr()

# Format the correlation matrix to set precision
formatted_correlation = correlation_matrix.style.background_gradient(cmap='coolwarm', axis=None).format(precision=2)

# Display the formatted correlation matrix
formatted_correlation
# Out:
# <style type="text/css">
# #T_5ecce_row0_col0, #T_5ecce_row1_col1, #T_5ecce_row2_col2, #T_5ecce_row3_col3, #T_5ecce_row4_col4, #T_5ecce_row5_col5, #T_5ecce_row6_col6 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_5ecce_row0_col1, #T_5ecce_row1_col0 {
#   background-color: #c7d7f0;
#   color: #000000;
# }
# #T_5ecce_row0_col2, #T_5ecce_row2_col0 {
#   background-color: #3f53c6;
#   color: #f1f1f1;
# }
# #T_5ecce_row0_col3, #T_5ecce_row3_col0 {
#   background-color: #445acc;
#   color: #f1f1f1;
# }
# #T_5ecce_row0_col4, #T_5ecce_row4_col0 {
#   background-color: #5d7ce6;
#   color: #f1f1f1;
# }
# #T_5ecce_row0_col5, #T_5ecce_row5_col0 {
#   background-color: #4e68d8;
#   color: #f1f1f1;
# }
# #T_5ecce_row0_col6, #T_5ecce_row6_col0 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_5ecce_row1_col2, #T_5ecce_row2_col1 {
#   background-color: #88abfd;
#   color: #000000;
# }
# #T_5ecce_row1_col3, #T_5ecce_row3_col1 {
#   background-color: #9fbfff;
#   color: #000000;
# }
# #T_5ecce_row1_col4, #T_5ecce_row4_col1 {
#   background-color: #7597f6;
#   color: #f1f1f1;
# }
# #T_5ecce_row1_col5, #T_5ecce_row5_col1 {
#   background-color: #a9c6fd;
#   color: #000000;
# }
# #T_5ecce_row1_col6, #T_5ecce_row6_col1 {
#   background-color: #8caffe;
#   color: #000000;
# }
# #T_5ecce_row2_col3, #T_5ecce_row3_col2 {
#   background-color: #e67259;
#   color: #f1f1f1;
# }
# #T_5ecce_row2_col4, #T_5ecce_row4_col2 {
#   background-color: #f3c7b1;
#   color: #000000;
# }
# #T_5ecce_row2_col5, #T_5ecce_row5_col2 {
#   background-color: #f59c7d;
#   color: #000000;
# }
# #T_5ecce_row2_col6, #T_5ecce_row6_col2 {
#   background-color: #c32e31;
#   color: #f1f1f1;
# }
# #T_5ecce_row3_col4, #T_5ecce_row4_col3 {
#   background-color: #f2cab5;
#   color: #000000;
# }
# #T_5ecce_row3_col5, #T_5ecce_row5_col3 {
#   background-color: #ec8165;
#   color: #f1f1f1;
# }
# #T_5ecce_row3_col6, #T_5ecce_row6_col3 {
#   background-color: #cc403a;
#   color: #f1f1f1;
# }
# #T_5ecce_row4_col5, #T_5ecce_row5_col4 {
#   background-color: #dddcdc;
#   color: #000000;
# }
# #T_5ecce_row4_col6, #T_5ecce_row6_col4 {
#   background-color: #f6a283;
#   color: #000000;
# }
# #T_5ecce_row5_col6, #T_5ecce_row6_col5 {
#   background-color: #e97a5f;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_5ecce">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_5ecce_level0_col0" class="col_heading level0 col0" >Rank</th>
#       <th id="T_5ecce_level0_col1" class="col_heading level0 col1" >Year</th>
#       <th id="T_5ecce_level0_col2" class="col_heading level0 col2" >NA_Sales</th>
#       <th id="T_5ecce_level0_col3" class="col_heading level0 col3" >EU_Sales</th>
#       <th id="T_5ecce_level0_col4" class="col_heading level0 col4" >JP_Sales</th>
#       <th id="T_5ecce_level0_col5" class="col_heading level0 col5" >Other_Sales</th>
#       <th id="T_5ecce_level0_col6" class="col_heading level0 col6" >Global_Sales</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_5ecce_level0_row0" class="row_heading level0 row0" >Rank</th>
#       <td id="T_5ecce_row0_col0" class="data row0 col0" >1.00</td>
#       <td id="T_5ecce_row0_col1" class="data row0 col1" >0.18</td>
#       <td id="T_5ecce_row0_col2" class="data row0 col2" >-0.40</td>
#       <td id="T_5ecce_row0_col3" class="data row0 col3" >-0.38</td>
#       <td id="T_5ecce_row0_col4" class="data row0 col4" >-0.27</td>
#       <td id="T_5ecce_row0_col5" class="data row0 col5" >-0.33</td>
#       <td id="T_5ecce_row0_col6" class="data row0 col6" >-0.43</td>
#     </tr>
#     <tr>
#       <th id="T_5ecce_level0_row1" class="row_heading level0 row1" >Year</th>
#       <td id="T_5ecce_row1_col0" class="data row1 col0" >0.18</td>
#       <td id="T_5ecce_row1_col1" class="data row1 col1" >1.00</td>
#       <td id="T_5ecce_row1_col2" class="data row1 col2" >-0.09</td>
#       <td id="T_5ecce_row1_col3" class="data row1 col3" >0.01</td>
#       <td id="T_5ecce_row1_col4" class="data row1 col4" >-0.17</td>
#       <td id="T_5ecce_row1_col5" class="data row1 col5" >0.04</td>
#       <td id="T_5ecce_row1_col6" class="data row1 col6" >-0.07</td>
#     </tr>
#     <tr>
#       <th id="T_5ecce_level0_row2" class="row_heading level0 row2" >NA_Sales</th>
#       <td id="T_5ecce_row2_col0" class="data row2 col0" >-0.40</td>
#       <td id="T_5ecce_row2_col1" class="data row2 col1" >-0.09</td>
#       <td id="T_5ecce_row2_col2" class="data row2 col2" >1.00</td>
#       <td id="T_5ecce_row2_col3" class="data row2 col3" >0.77</td>
#       <td id="T_5ecce_row2_col4" class="data row2 col4" >0.45</td>
#       <td id="T_5ecce_row2_col5" class="data row2 col5" >0.63</td>
#       <td id="T_5ecce_row2_col6" class="data row2 col6" >0.94</td>
#     </tr>
#     <tr>
#       <th id="T_5ecce_level0_row3" class="row_heading level0 row3" >EU_Sales</th>
#       <td id="T_5ecce_row3_col0" class="data row3 col0" >-0.38</td>
#       <td id="T_5ecce_row3_col1" class="data row3 col1" >0.01</td>
#       <td id="T_5ecce_row3_col2" class="data row3 col2" >0.77</td>
#       <td id="T_5ecce_row3_col3" class="data row3 col3" >1.00</td>
#       <td id="T_5ecce_row3_col4" class="data row3 col4" >0.44</td>
#       <td id="T_5ecce_row3_col5" class="data row3 col5" >0.73</td>
#       <td id="T_5ecce_row3_col6" class="data row3 col6" >0.90</td>
#     </tr>
#     <tr>
#       <th id="T_5ecce_level0_row4" class="row_heading level0 row4" >JP_Sales</th>
#       <td id="T_5ecce_row4_col0" class="data row4 col0" >-0.27</td>
#       <td id="T_5ecce_row4_col1" class="data row4 col1" >-0.17</td>
#       <td id="T_5ecce_row4_col2" class="data row4 col2" >0.45</td>
#       <td id="T_5ecce_row4_col3" class="data row4 col3" >0.44</td>
#       <td id="T_5ecce_row4_col4" class="data row4 col4" >1.00</td>
#       <td id="T_5ecce_row4_col5" class="data row4 col5" >0.29</td>
#       <td id="T_5ecce_row4_col6" class="data row4 col6" >0.61</td>
#     </tr>
#     <tr>
#       <th id="T_5ecce_level0_row5" class="row_heading level0 row5" >Other_Sales</th>
#       <td id="T_5ecce_row5_col0" class="data row5 col0" >-0.33</td>
#       <td id="T_5ecce_row5_col1" class="data row5 col1" >0.04</td>
#       <td id="T_5ecce_row5_col2" class="data row5 col2" >0.63</td>
#       <td id="T_5ecce_row5_col3" class="data row5 col3" >0.73</td>
#       <td id="T_5ecce_row5_col4" class="data row5 col4" >0.29</td>
#       <td id="T_5ecce_row5_col5" class="data row5 col5" >1.00</td>
#       <td id="T_5ecce_row5_col6" class="data row5 col6" >0.75</td>
#     </tr>
#     <tr>
#       <th id="T_5ecce_level0_row6" class="row_heading level0 row6" >Global_Sales</th>
#       <td id="T_5ecce_row6_col0" class="data row6 col0" >-0.43</td>
#       <td id="T_5ecce_row6_col1" class="data row6 col1" >-0.07</td>
#       <td id="T_5ecce_row6_col2" class="data row6 col2" >0.94</td>
#       <td id="T_5ecce_row6_col3" class="data row6 col3" >0.90</td>
#       <td id="T_5ecce_row6_col4" class="data row6 col4" >0.61</td>
#       <td id="T_5ecce_row6_col5" class="data row6 col5" >0.75</td>
#       <td id="T_5ecce_row6_col6" class="data row6 col6" >1.00</td>
#     </tr>
#   </tbody>
# </table>

# %%
# filter out inputs that have the highest correlation with NA_Sales
X = df[["EU_Sales"]] # (16597, 2) Matrix (Inputs)
y = df[["NA_Sales"]] # (16597, 1) Vector (Outputs)
X.shape

# %%
# perform the regression using scikit-learn
from sklearn import linear_model
regr = linear_model.LinearRegression()
regr.fit(X, y)

# %%
# the theta's
print('theta_0', regr.intercept_, 'theta_1', regr.coef_)

# perform prediction on the complete training set
pred = regr.predict(X)

# visualize how the model fits the training data
plt.scatter(X, y)
plt.plot(X, pred, color="r")
plt.xlabel('Population of City in 10,000s')
plt.ylabel('Profit in $10,000s')
plt.title('Profit as a function of city population')
plt.show()
